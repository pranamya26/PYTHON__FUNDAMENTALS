# %%
Introduction to python programming

# %%
Understanding The Variables In Python

# %%
a=2
b=3

# %%
c=a+b
print(c)
# Out:
# 5

# %%
Rules For Declaring The Variables In Python

# %%
Rule No 1:No Namespaces while declaring the variable name

# %%
firstname = 'Faiyaz'
print(firstname)
# Out:
# Faiyaz

# %%
first_name ='faiyaz'
print(first_name)
# Out:
# faiyaz

# %%
Rule No 2 :A Variable name should not end with spaces

# %%
1name = 'anad'
print(1name)
# Out:
#   Cell In[7], line 1
#     1name = 'anad'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = 'anad'
print(name1)
# Out:
# anad

# %%
Rule No 3 :A Variable Should not contain any special charecters

# %%
name@ ='vanacha'
print(name@)
# Out:
#   Cell In[9], line 1
#     name@ ='vanacha'
#           ^
# SyntaxError: invalid syntax

# %%
Introduction to Data types in Python:
1.string(str)
2.Number(int,float)
3.lists(list)
4.tuples(tuple)
5.dictionaries(dict)

# %%
Python programming is a case sensitive programming language

# %%
classification of Data types:
Broadly data types are categorized as 
1.mutable databases:which we will be able to edit/modify
2.immutable databases:which we will not be able to modify

# %%
Introduction to string data type

# %%
#Definition:A string is nothing but a series of charecters decalared in quotes
#classified: It is classified as immutable

# %%
HOW DO WE DEFINE?
1.single quotes
2.double quotes

# %%
name ='akash'
print(name)
# Out:
# akash

# %%
name2 ="Hajera"
print(name2)
# Out:
# Hajera

# %%
Introduction to string methods:

# %%
type(name)
# Out:
# str

# %%
# is used for comments

# %%
fullname ='kiran reddy'
print(fullname)
# Out:
# kiran reddy

# %%
#TO GET STARTING LETTER OF BOTH THE WORDS CAPITAL:
print(fullname.title())
# Out:
# Kiran Reddy

# %%
#TO GET ALL LETTERS OF BOTH THE WORDS CAPITAL:
print(fullname.upper())
# Out:
# KIRAN REDDY

# %%
#TO GET ALL LETTERS OF BOTH THE WORDS in sm:
