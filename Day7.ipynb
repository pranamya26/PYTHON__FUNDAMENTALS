# %%
#Introduction to dictionaries:

# %%
#Definition : A Dictionary is a combination of key value of parts

# %%
#Classification : It is a mutable.

# %%
#how to define/declare dictionaries ---{}

# %%
#I want to create a game 
alien = {'color':'green','points':5}
print(alien)
# Out:
# {'color': 'green', 'points': 5}

# %%
type(alien)
# Out:
# dict

# %%
#How to add new Key value pairs 
#I want to add start_position : level 1 will be done

# %%
alien['start_position'] = 'level 1'

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level 1'}

# %%
#How to access the new key value pairs will also be

# %%
alien['color']
# Out:
# 'green'

# %%
alien['start_position']
# Out:
# 'level 1'

# %%
alien['points']
# Out:
# 5

# %%
#WE give the key and get the values

# %%
#TO create another account in instagram

# %%
user_account = {'username':'codetraining','username':'code','dob':'12-12-2010','pw':'123456'}

# %%
print(user_account)
# Out:
# {'username': 'code', 'dob': '12-12-2010', 'pw': '123456'}

# %%
#How to delete the key values 
#I want to delete the username

# %%
del user_account['username']

# %%
print(user_account)
# Out:
# {'dob': '12-12-2010', 'pw': '123456'}

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level 1'}

# %%
alien['level 1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 alien['level 1']
#
# KeyError: 'level 1'

# %%
#implementation for a for loop on top of dictionary
#general syntax of a dictionary

# %%
#for tempvar1,tempvar2 in mainvar.items():
   # print(tempvar1)
   # print(tempvar2)

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 'level 1'}

# %%
for k,v in alien.items():
    print(k)
    print(v)
# Out:
# color
# green
# points
# 5
# start_position
# level 1

# %%
for k,v in alien.items():
    print(k)
    print(v)

# %%
for k,v in alien.items():
    print(f"key:{k}"
    print(f"value : {v}")
# Out:
#   Cell In[21], line 2
#     print(f"key:{k}"
#          ^
# SyntaxError: '(' was never closed

# %%
for k,v in alien.items():
    print(f"key:{k}")
    print(f"value : {v}")
# Out:
# key:color
# value : green
# key:points
# value : 5
# key:start_position
# value : level 1
