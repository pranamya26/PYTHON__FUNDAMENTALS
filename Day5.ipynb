# %%
Continuation of list data type:

# %%
Organizing the list data type:

# %%
cars = ['kia','audi','maruthi','hyndayi','wolksvogan','benz','suzuki','bmw']

# %%
print(cars)
# Out:
# ['kia', 'audi', 'maruthi', 'hyndayi', 'wolksvogan', 'benz', 'suzuki', 'bmw']

# %%
#I want to organize the list in the alphabetical order
#A-Z order

# %%
# Two approaches
#1. Temporary approaches( we will get the original order)
#2. Permanent approaches ( changes are applied permanentlyaaaaaaa0

# %%
print(sorted(cars))
# Out:
# ['audi', 'benz', 'bmw', 'hyndayi', 'kia', 'maruthi', 'suzuki', 'wolksvogan']

# %%
print(cars)
# Out:
# ['kia', 'audi', 'maruthi', 'hyndayi', 'wolksvogan', 'benz', 'suzuki', 'bmw']

# %%
cars.sort()

# %%
print(cars)
# Out:
# ['audi', 'benz', 'bmw', 'hyndayi', 'kia', 'maruthi', 'suzuki', 'wolksvogan']

# %%
# I want to know how many cars
len(cars)
# Out:
# 8

# %%
#I want to get the opposite of the order

# %%
cars.reverse()
print(cars)
# Out:
# ['wolksvogan', 'suzuki', 'maruthi', 'kia', 'hyndayi', 'bmw', 'benz', 'audi']

# %%
#Introduction to slicing:

# %%
#General syntax of slicing
#[start_value:stop_value:step_count]

# %%
students =['Divya','Harika','Naveen','Hafsa','Karthik','vicky']

# %%
#Note: Last value is always exclusive to include the last value increment the index by one
#req: i want to get divya and harika in the slice?

# %%
print(students[0:2])
# Out:
# ['Divya', 'Harika']

# %%
print(students[2:4])
# Out:
# ['Naveen', 'Hafsa']

# %%
print(students[0:6:3])
# Out:
# ['Divya', 'Hafsa']

# %%
#INTRODUCTION TO TUPLE DATA TYPE:

# %%
#Defintion: An immutable list is called an tuple data type.
#Classification : It is classified as an immutable data type.
#How do you define tuple data type?

# %%
area_size = (27,30)

# %%
print(area_size)
# Out:
# (27, 30)

# %%
type(area_size)
# Out:
# tuple

# %%
area_size[0] = 28
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 area_size[0] = 28
#
# TypeError: 'tuple' object does not support item assignment
