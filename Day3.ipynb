# %%
Introduction to f strings :

# %%
#general syntax of f strings

# %%
f"custom message,{place_holder1}{place_holder2}---------{place_holder}"

# %%
first_name = 'kiran'
last_name =  'reddy'

# %%
#To get the full name using substrings

# %%
fullname= f"{first_name} {last_name}"
print (fullname)
# Out:
# kiran reddy

# %%
#To get the first letter capital we will do title
print(fullname.title())
# Out:
# Kiran Reddy

# %%
message = f"keep up the great work ,{fullname.title()}"

# %%
print(message)
# Out:
# keep up the great work ,Kiran Reddy

# %%
Adding whitespaces to strings:

# %%
print("Favourite_programming_languageCPYTHONJAVAC++JAVASCRIPT")
# Out:
# Favourite_programming_languageCPYTHONJAVAC++JAVASCRIPT

# %%
print("Favourite_programming_language\nC\nPYTHON\nJAVA\nC++\nJAVASCRIPT\n")
# Out:
# Favourite_programming_language
# C
# PYTHON
# JAVA
# C++
# JAVASCRIPT

# %%
\n-------> new line delimiter

# %%
print("Favourite_programming_language\n\tC\n\tPYTHON\n\tJAVA\n\tC++\n\tJAVASCRIPT\n\t")
# Out:
# Favourite_programming_language
# 	C
# 	PYTHON
# 	JAVA
# 	C++
# 	JAVASCRIPT

# %%
Removing whitespaces from strings:

# %%
name ="   python"
print(name)
# Out:
#    python

# %%
name2 ="python  "
print(name2)
# Out:
# python

# %%
name.lstrip()#if space on the left side
# Out:
# 'python'

# %%
name2.rstrip()#if space is on the right side
# Out:
# 'python'

# %%
name3 ="     PYTHON   "

# %%
name3.strip()#if we donot know where space exist
# Out:
# 'PYTHON'

# %%
# zen of python

# %%
import
