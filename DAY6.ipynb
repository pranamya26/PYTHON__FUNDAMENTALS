# %%
Introduction to tuple datatype:

# %%
Definition: An immutable list is called a tuple datatype.

# %%
classification:It is classified as an immutable datatype.

# %%
how do we define the tuple datatype -----()

# %%
dimension = (20,60)
print(dimension)
# Out:
# (20, 60)

# %%
type(dimension)
# Out:
# tuple

# %%
dimension[0]=25
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dimension[0]=25
#
# TypeError: 'tuple' object does not support item assignment

# %%
Introduction to looping statements :

# %%
Introduction to for loop:

# %%
#General syntax

# %%
for tempvar in mainvar:
    print(tempvar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for tempvar in mainvar:
#       2     print(tempvar)
#
# NameError: name 'mainvar' is not defined

# %%
students = ['vicky','sudhakar','kavya','neha','sai','david']
print(students)
# Out:
# ['vicky', 'sudhakar', 'kavya', 'neha', 'sai', 'david']

# %% [markdown]
# message = f"keep up the good work,{students[0].title()}"
# print(message)

# %%
message = f"keep up the good work,{students[0].title()}"
print(message)
# Out:
# keep up the good work,Vicky

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
    print(f"I will be looking forward,{x.title()}")
# Out:
# keep up the good work,Vicky
# I will be looking forward,Vicky
# keep up the good work,Sudhakar
# I will be looking forward,Sudhakar
# keep up the good work,Kavya
# I will be looking forward,Kavya
# keep up the good work,Neha
# I will be looking forward,Neha
# keep up the good work,Sai
# I will be looking forward,Sai
# keep up the good work,David
# I will be looking forward,David

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
    print(f"I will be looking forward,{x.title()}\n")
# Out:
# keep up the good work,Vicky
# I will be looking forward,Vicky
#
# keep up the good work,Sudhakar
# I will be looking forward,Sudhakar
#
# keep up the good work,Kavya
# I will be looking forward,Kavya
#
# keep up the good work,Neha
# I will be looking forward,Neha
#
# keep up the good work,Sai
# I will be looking forward,Sai
#
# keep up the good work,David
# I will be looking forward,David

# %%
#enhancement of code

# %%
for x in students:
    print(f"keep up the good work,{x.title()}")
    print(f"I will be looking forward,{x.title()}")
print("Thank you"
