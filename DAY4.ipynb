# %%
num = 1
num2 = 4

# %%
type(num)
# Out:
# int

# %%
x=0.1
print(x)
# Out:
# 0.1

# %%
type(x)
# Out:
# float

# %%
Introduction to list data type:

# %%
classification: It is classified as a mutable data type.

# %%
how do we define a list ----> []

# %%
students = ['vicky','abdul','shree','anwar','murthi']
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murthi']

# %%
Introduction to indexing : 0,1,2,3-----

# %%
#how to acess the elements in the list?
#i want to acess abduls name

# %%
print(students[1])
# Out:
# abdul

# %%
print(students[1].title())
# Out:
# Abdul

# %%
#1.How to add elements to the list?
#2.How to modify elements of the list?
#3.How to delete elements of the list?

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murthi']

# %%
students.append('varun')
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murthi', 'varun']

# %%
students.append('praneeth')
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murthi', 'varun', 'praneeth']

# %%
#It will be added to the end of the list
#required i want to add at the second index divya

# %%
students.insert(2,'divya')

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'divya', 'shree', 'anwar', 'murthi', 'varun', 'praneeth']

# %%
#required i want to modify the name divya with dinesh

# %%
students[2] = 'dinesh'

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'dinesh', 'shree', 'anwar', 'murthi', 'varun', 'praneeth']

# %%
#required I want to delete the name vicky in the list

# %%
#For deleting there are two different approaches
1.temp deleting: It will be storing a carboncopy of the deleted item to the variable assingment
we will be using method call pop()
By default pop will be deleting last element in the list
2.Permanent delete

# %%
x = students.pop()
print(x)
# Out:
# praneeth

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'dinesh', 'shree', 'anwar', 'murthi', 'varun']

# %%
a= students.pop(0)
print(students)
# Out:
# ['abdul', 'dinesh', 'shree', 'anwar', 'murthi', 'varun']

# %%
print(a)
# Out:
# vicky

# %%
Required i want to delete a specific people

# %%
 del.students[1]
# Out:
#   Cell In[26], line 1
#     del.students[1]
#        ^
# SyntaxError: invalid syntax

# %%
print(students)
# Out:
# ['abdul', 'dinesh', 'shree', 'anwar', 'murthi', 'varun']
